# %%
import pandas as pd
import glob 
import numpy as np

# %%
# Data from https://home.treasury.gov/interest-rates-data-csv-archive

df = pd.concat(
    map(pd.read_csv, ['yield-curve-rates-1990-2021.csv', 'daily-treasury-rates2022.csv']), ignore_index=True)

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")
df['dates_cleaned'] = pd.to_datetime(df['date'])
df
# Out:
#             date  1_mo  2_mo  3_mo  6_mo  1_yr  2_yr  3_yr  5_yr  7_yr  10_yr  \
# 0       12/31/21  0.06  0.05  0.06  0.19  0.39  0.73  0.97  1.26  1.44   1.52
# 1       12/30/21  0.06  0.06  0.05  0.19  0.38  0.73  0.98  1.27  1.44   1.52
# 2       12/29/21  0.01  0.02  0.05  0.19  0.38  0.75  0.99  1.29  1.47   1.55
# 3       12/28/21  0.03  0.04  0.06  0.20  0.39  0.74  0.99  1.27  1.41   1.49
# 4       12/27/21  0.04  0.05  0.06  0.21  0.33  0.76  0.98  1.26  1.41   1.48
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
# 8132  01/07/2022  0.05  0.05  0.10  0.24  0.43  0.87  1.17  1.50  1.69   1.76
# 8133  01/06/2022  0.04  0.05  0.10  0.23  0.45  0.88  1.15  1.47  1.66   1.73
# 8134  01/05/2022  0.05  0.06  0.09  0.22  0.41  0.83  1.10  1.43  1.62   1.71
# 8135  01/04/2022  0.06  0.05  0.08  0.22  0.38  0.77  1.02  1.37  1.57   1.66
# 8136  01/03/2022  0.05  0.06  0.08  0.22  0.40  0.78  1.04  1.37  1.55   1.63
#
#       20_yr  30_yr dates_cleaned
# ...

# %%
df.plot(x="dates_cleaned",y="2_yr")
# Out:
# <AxesSubplot:xlabel='dates_cleaned'>

# %%
df.plot(x="dates_cleaned",y="10_yr")
# Out:
# <AxesSubplot:xlabel='dates_cleaned'>

# %%
df.to_csv('treasuryyieldcurve.csv')

# %%
df.to_json('treasuryyieldcurve.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 df.to_json('treasuryyieldcurve.json',index=False)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py:2621, in NDFrame.to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent, storage_options)
#    2618 config.is_nonnegative_int(indent)
#    2619 indent = indent or 0
# -> 2621 return json.to_json(
#    2622     path_or_buf=path_or_buf,
#    2623     obj=self,
#    2624     orient=orient,
#    2625     date_format=date_format,
#    2626     double_precision=double_precision,
#    2627     force_ascii=force_ascii,
#    2628     date_unit=date_unit,
#    2629     default_handler=default_handler,
#    2630     lines=lines,
#    2631     compression=compression,
# ...

# %%
df = df.sort_values(by=['dates_cleaned'])
# df.pop('date')
df.plot(x="1_mo",y="dates_cleaned")
# Out:
#       1_mo  2_mo  3_mo  6_mo  1_yr  2_yr  3_yr  5_yr  7_yr  10_yr  20_yr  \
# 8007   NaN   NaN  7.83  7.89  7.81  7.87  7.90  7.87  7.98   7.94    NaN
# 8006   NaN   NaN  7.89  7.94  7.85  7.94  7.96  7.92  8.04   7.99    NaN
# 8005   NaN   NaN  7.84  7.90  7.82  7.92  7.93  7.91  8.02   7.98    NaN
# 8004   NaN   NaN  7.79  7.85  7.79  7.90  7.94  7.92  8.03   7.99    NaN
# 8003   NaN   NaN  7.79  7.88  7.81  7.90  7.95  7.92  8.05   8.02    NaN
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...    ...    ...
# 8012  1.27  1.68  1.73  2.52  2.79  2.84  2.85  2.88  2.92   2.88   3.35
# 8011  1.33  1.71  1.90  2.59  2.77  2.82  2.82  2.82  2.87   2.82   3.31
# 8010  1.36  1.70  1.90  2.62  2.82  2.97  2.99  2.96  2.99   2.93   3.42
# 8009  1.55  1.90  1.95  2.64  2.87  3.03  3.05  3.05  3.07   3.01   3.45
# 8008  1.57  1.92  1.98  2.68  2.96  3.12  3.14  3.13  3.16   3.09   3.53
#
#       30_yr dates_cleaned
# 8007   8.00    1990-01-02
# 8006   8.04    1990-01-03
# ...

# %%
data = []
df2 =
# Out:
# {8007: {'date': '1/2/90',
#   '1_mo': nan,
#   '2_mo': nan,
#   '3_mo': 7.83,
#   '6_mo': 7.89,
#   '1_yr': 7.81,
#   '2_yr': 7.87,
#   '3_yr': 7.9,
#   '5_yr': 7.87,
#   '7_yr': 7.98,
#   '10_yr': 7.94,
#   '20_yr': nan,
#   '30_yr': 8.0,
#   'dates_cleaned': Timestamp('1990-01-02 00:00:00')},
#  8006: {'date': '1/3/90',
#   '1_mo': nan,
#   '2_mo': nan,
#   '3_mo': 7.89,
#   '6_mo': 7.94,
#   '1_yr': 7.85,
#   '2_yr': 7.94,
#   '3_yr': 7.96,
#   '5_yr': 7.92,
#   '7_yr': 8.04,
#   '10_yr': 7.99,
#   '20_yr': nan,
#   '30_yr': 8.04,
#   'dates_cleaned': Timestamp('1990-01-03 00:00:00')},
#  8005: {'date': '1/4/90',
#   '1_mo': nan,
#   '2_mo': nan,
#   '3_mo': 7.84,
#   '6_mo': 7.9,
#   '1_yr': 7.82,
#   '2_yr': 7.92,
#   '3_yr': 7.93,
#   '5_yr': 7.91,
#   '7_yr': 8.02,
#   '10_yr': 7.98,
#   '20_yr': nan,
#   '30_yr': 8.04,
#   'dates_cleaned': Timestamp('1990-01-04 00:00:00')},
#  8004: {'date': '1/5/90',
#   '1_mo': nan,
#   '2_mo': nan,
#   '3_mo': 7.79,
#   '6_mo': 7.85,
# ...
